# %%
from IPython import display

import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import torch
import torch.nn as nn
import torch.nn.functional  as F

# %%
import scipy.stats as stats

# %% [markdown]
# ## STEP 1 :  Get the Data

# %% [markdown]
# ## 1 :  Get the Data

# %%
wine = pd.read_csv(r"wine_clean_dataset_after_EDA.csv" , index_col = 0)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.shape
# Out:
# (1353, 12)

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1353.000000       1353.000000  1353.000000     1353.000000
# mean        8.310569          0.529970     0.270813        2.515595
# std         1.740485          0.183189     0.193877        1.336413
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1353.000000          1353.000000           1353.000000  1353.000000
# mean      0.087375            15.849963             46.331486     0.996711
# std       0.045186            10.424959             32.034659     0.001866
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.090000            21.000000             63.000000     0.997820
# max       0.467000            72.000000            165.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1353.000000  1353.000000  1353.000000  1353.000000
# mean      3.311397     0.655558    10.431941     5.623060
# std       0.153322     0.158402     1.081120     0.822106
# min       2.860000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     1.620000    14.900000     8.000000

# %% [markdown]
# ## 2. Normalization of Data

# %%
# z-score all variables except for quality

# find the columns we want to normalize (all except quality)
cols2zscore = wine.columns
cols2zscore = cols2zscore.drop('quality')

# z-score (written out for clarity)
# for col in cols2zscore:
    
#     mean_val   = np.mean(wine[col])
#     std_val    = np.std(wine[col],ddof=1)
#     wine[col]  = (wine[col]-mean_val) / std_val

# can also do more compactly
wine[cols2zscore] = wine[cols2zscore].apply(stats.zscore)

wine.describe()
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   1.353000e+03      1.353000e+03  1.353000e+03    1.353000e+03
# mean    2.100644e-17      3.098449e-16 -2.100644e-17   -2.100644e-17
# std     1.000370e+00      1.000370e+00  1.000370e+00    1.000370e+00
# min    -2.132705e+00     -2.238797e+00 -1.397346e+00   -1.209351e+00
# 25%    -6.957926e-01     -7.643609e-01 -9.329625e-01   -4.608027e-01
# 50%    -2.359807e-01     -5.444729e-02 -5.579317e-02   -2.362381e-01
# 75%     5.112136e-01      6.008575e-01  8.213762e-01    6.318125e-02
# max     4.362138e+00      5.734079e+00  2.678911e+00    9.719456e+00
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  1.353000e+03         1.353000e+03          1.353000e+03  1.353000e+03
# mean   1.470451e-16         1.050322e-17          9.452897e-17  9.742786e-14
# std    1.000370e+00         1.000370e+00          1.000370e+00  1.000370e+00
# min   -1.668717e+00        -1.424989e+00         -1.259461e+00 -3.559786e+00
# 25%   -3.846707e-01        -8.492346e-01         -7.598171e-01 -5.956490e-01
# 50%   -1.854221e-01        -1.775208e-01         -2.601734e-01 -6.037545e-03
# 75%    5.810394e-02         4.941930e-01          5.205199e-01  5.942941e-01
# max    8.404405e+00         5.388108e+00          3.705749e+00  3.740675e+00
#
#                  pH     sulphates       alcohol      quality
# count  1.353000e+03  1.353000e+03  1.353000e+03  1353.000000
# mean   2.100644e-15 -4.411352e-16 -2.730837e-16     5.623060
# std    1.000370e+00  1.000370e+00  1.000370e+00     0.822106
# min   -2.945193e+00 -2.056027e+00 -1.880174e+00     3.000000
# 25%   -6.615761e-01 -6.666405e-01 -8.623337e-01     5.000000
# 50%   -9.114213e-03 -2.245629e-01 -2.146174e-01     6.000000
# 75%    5.781015e-01  4.701305e-01  6.181607e-01     6.000000
# max    4.558119e+00  6.090831e+00  4.134335e+00     8.000000

# %% [markdown]
# ## 3. Creating Boolean Label

# %%
import warnings
warnings.filterwarnings(action = "ignore")

# %%
# create a new column for binarized (boolean) quality
wine['boolQuality'] = 0

# Binarizing the column
wine['boolQuality'][wine['quality']>5] = 1

wine[['quality','boolQuality']]
# Out:
#       quality  boolQuality
# 0           5            0
# 1           5            0
# 2           5            0
# 3           6            1
# 4           5            0
# ...       ...          ...
# 1354        6            1
# 1355        5            0
# 1356        6            1
# 1357        5            0
# 1358        6            1
#
# [1353 rows x 2 columns]

# %%
wine['boolQuality'].value_counts()
# Out:
# 1    716
# 0    637
# Name: boolQuality, dtype: int64

# %% [markdown]
# ## 4. Converting Data to tensor

# %%
pred_col = wine.columns.drop(labels = ['quality', 'boolQuality'])
pred_col
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
arr_data = wine[pred_col].values

# %%
arr_data
# Out:
# array([[-0.5233631 ,  0.92850995, -1.39734632, ...,  1.29580955,
#         -0.60348657, -0.95486462],
#        [-0.29345717,  1.91146719, -1.39734632, ..., -0.72682228,
#          0.15436075, -0.58474102],
#        [-0.29345717,  1.25616236, -1.19095353, ..., -0.33534515,
#         -0.03510108, -0.58474102],
#        ...,
#        [-1.38551036,  0.10937892, -0.88136434, ...,  1.36105574,
#          0.65959229,  0.71069156],
#        [-1.38551036,  0.6281619 , -0.77816795, ...,  1.68728668,
#          0.34382257, -0.21461743],
#        [-1.32803388, -1.20123074,  1.02776898, ...,  0.51285529,
#          0.02805286,  0.52562976]])

# %% [markdown]
# #### Predictiors or Independent features

# %%
data = torch.tensor(arr_data ,dtype = torch.float )
data[:5]
# Out:
# tensor([[-0.5234,  0.9285, -1.3973, -0.4608, -0.2518, -0.4654, -0.3851,  0.5836,
#           1.2958, -0.6035, -0.9549],
#         [-0.2935,  1.9115, -1.3973,  0.0632,  0.2352,  0.8780,  0.6454,  0.0476,
#          -0.7268,  0.1544, -0.5847],
#         [-0.2935,  1.2562, -1.1910, -0.1614,  0.1024, -0.0816,  0.2395,  0.1548,
#          -0.3353, -0.0351, -0.5847],
#         [ 1.6607, -1.3651,  1.4922, -0.4608, -0.2740,  0.1104,  0.4268,  0.6908,
#          -0.9878, -0.4772, -0.5847],
#         [-0.5234,  0.7101, -1.3973, -0.5357, -0.2740, -0.2735, -0.1977,  0.5836,
#           1.2958, -0.6035, -0.9549]])

# %%
type(data)
# Out:
# torch.Tensor

# %% [markdown]
# #### Labels

# %%
arr_label = wine["boolQuality"].values

# %%
arr_label
# Out:
# array([0, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
labels = torch.tensor(arr_label ,dtype = torch.float)

# %%
labels
# Out:
# tensor([0., 0., 0.,  ..., 1., 0., 1.])

# %%
labels[:,None]
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [0.],
#         [1.]])

# %%
labels = labels[:,None]

# %% [markdown]
# ## 5. Convert the Data into Tensor Dataset

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader,TensorDataset

# %%
# scikitlearn to split the data
train_data,test_data, train_labels,test_labels = train_test_split(data, labels, test_size=.2)


# convert them into PyTorch Datasets (note: already converted to tensors)
train_data = TensorDataset(train_data,train_labels)
test_data  = TensorDataset(test_data,test_labels)


# finally, translate into dataloader objects

batchsize    = 32 
train_loader = DataLoader(train_data, batch_size=batchsize, shuffle=True  ,drop_last=True)
test_loader  = DataLoader(test_data, batch_size=test_data.tensors[0].shape[0] )

# %%
for X,y in train_loader:
    print(X.shape,y.shape)
# Out:
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])
# torch.Size([32, 11]) torch.Size([32, 1])

# %%
for X,y in test_loader:
    print(X.shape,y.shape)
# Out:
# torch.Size([271, 11]) torch.Size([271, 1])

# %% [markdown]
# ## 6. Custom Class for ANN model

# %%
# create a class for the model

class ANNwine(nn.Module):
    
    def __init__(self ,act_func):
        super().__init__()

        ### input layer
        self.input = nn.Linear(11,16)

        ### hidden layers(fc : Fully Connected)
        self.fc1 = nn.Linear(16,32) 
        # 16 : number of input features to self.fc1
        self.bnorm1 = nn.BatchNorm1d(16) 
        
        # 32 : number of input features to self.fc2
        self.bnorm2 = nn.BatchNorm1d(32) 
        self.fc2 = nn.Linear(32,32)
        

        ### output layer
        self.output = nn.Linear(32,1)
        
        # Activation Function
        self.act_func = act_func

    # forward pass
    def forward(self,x,DoBN):
        
        #actfunc = getattr(torch , self.act_func)
        
        x = actfunc( self.input(x) )
        
        if DoBN :
            
            # Hidden -Layer :1 
            x = self.bnorm1(x)
            x = actfunc( self.fc1(x) )
            
            # Hidden -Layer : 2 
            x = self.bnorm2(x)
            x = actfunc( self.fc2(x) )
            
        else :
            
            # Hidden Layer -1 
            x = actfunc( self.fc1(x) )
            
            # Hidden Layer -2
            x = actfunc( self.fc2(x) )
            
                
        return self.output(x)

# %%
# test the model
# use sigmoid, relu, tanh

net = ANNwine(act_func = 'sigmoid')
net( x = torch.randn(10,11) ,DoBN = True  ).shape
# Out:
# torch.Size([10, 1])

# %% [markdown]
# ## 7. Custom Train Model Function

# %%
# a function that trains the model

def trainTheModel(Model, train_loader , test_loader ,LR ,epochs ,DoBN):

    # loss function and optimizer
    lossfunc = nn.BCEWithLogitsLoss()  # Binary -classification
    optimizer = torch.optim.SGD(Model.parameters(),lr=LR)

    # initialize losses
    losses   = torch.zeros(epochs)
    trainAcc = []
    testAcc  = []

    # loop over epochs
    for epochi in range(epochs):

        # switch on training mode
        Model.train()

        # loop over training data batches
        batchAcc  = []
        batchLoss = []
    
        for X,y in train_loader:

            # forward pass and loss
            yHat_train = Model(X ,DoBN )  
            #print("Y predicted : " , yHat_train.shape)
            #print("Y Actual : " ,y.shape)
            
            loss = lossfunc(yHat_train,y)

            # backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # loss from this batch
            batchLoss.append(loss.item())

            # compute training accuracy for this batch
            batchAcc.append( 100*torch.mean( ( (yHat_train>0) == y ).float() ).item() )
            # end of batch loop...

        # now that we've trained through the batches, get their average training accuracy
        trainAcc.append( np.mean(batchAcc) )

        # and get average losses across the batches
        losses[epochi] = np.mean(batchLoss)
    
        # ****** TESTING *******
        Model.eval()
        
        # extract X,y from test dataloader
        X,y = next(iter(test_loader)) 
        
        with torch.no_grad(): # deactivates autograd
            yHat_test = Model(X ,DoBN)
            
        # test accuracy    
        testAcc.append( 100*torch.mean( ( (yHat_test>0) == y ).float() ).item() )
  
    # function output for each iteration(epoch)
    return trainAcc,testAcc,losses

# %% [markdown]
# ## 8. Parametric Experiment

# %%
# This cell takes 3 mins
numepochs = 1000
LR = 0.01

# list activation functions to test
activation_funs = [ 'relu', 'tanh', 'sigmoid' ]

trainByAct_func = np.zeros((numepochs,len(activation_funs)))
testByAct_func  = np.zeros((numepochs,len(activation_funs)))
lossByAct_func  = np.zeros((numepochs,len(activation_funs)))

# %%
# Takes : 
for ai,actfunc in enumerate(activation_funs):
    
    # create a model and train it
    ANN_wine_model = ANNwine(act_func = actfunc)
    
    trainByAct_func[:,ai],testByAct_func[:,ai],lossByAct_func[: , ai] =  trainTheModel(Model = ANN_wine_model,
                                                               train_loader = train_loader ,
                                                               test_loader = test_loader,
                                                               LR = LR,
                                                               epochs = numepochs,
                                                               DoBN  = True)

# %% [markdown]
# ## 9. Results Visualization

# %%
# plot some results
fig,ax = plt.subplots(1,3,figsize=(8,3))

ax[0].plot(lossByAct_func)
ax[0].set_xlabel('Number of Iterations')
ax[0].set_ylabel('Losses')

ax[0].set_title('Losses with Activation function')
ax[0].legend(activation_funs)

ax[1].plot(trainByAct_func)
ax[1].set_title('Train accuracy')

ax[2].plot(testByAct_func)
ax[2].set_title('Test accuracy')


# common features
for i in range(1,3):
    
    ax[i].legend(activation_funs)
    ax[i].set_xlabel('Number of Iterations')
    ax[i].set_ylabel('Accuracy (%)')
    ax[i].set_ylim([50,100])
    ax[i].grid()

plt.tight_layout()

plt.show()
