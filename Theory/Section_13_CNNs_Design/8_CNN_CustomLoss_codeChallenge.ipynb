# %% [markdown]
# ## 1. Standard Import

# %%
from IPython import display

import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import torch
import torch.nn as nn
import torch.nn.functional  as F
from scipy.signal import convolve2d

# %%
# for getting summary info on models
from torchsummary import summary

# %%
from torch.utils.data import DataLoader,TensorDataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Create Gaussian blurs with varying widths and occluding bars

# %%
# Number of Gaussian blurs images
nGauss = 1500

# Pixel size : heightxwidth = 91x91
imgSize   = 91

x = np.linspace(start=-4, stop=4, num=imgSize)

# Return coordinate matrices from coordinate vectors.
X,Y = np.meshgrid(x,x)

# vary the width smoothly
widths = np.linspace(2,20,nGauss)

# initialize tensors containing images and labels
# 1 : grey scale channel
images = torch.zeros(nGauss, 1, imgSize, imgSize)
# labels = torch.zeros(2*nPerClass)

for i in range(nGauss):

    # create the gaussian with random centers
    ro = 1.5*np.random.randn(2) # ro = random offset
    G  = np.exp( -( (X-ro[0])**2 + (Y-ro[1])**2) / widths[i] )

    # add noise
    G  = G + np.random.randn(imgSize,imgSize)/5

    # add a random bar randomly
    i1 = np.random.choice(np.arange(2,28))
    i2 = np.random.choice(np.arange(2,6))
    
    if np.random.randn()>0:
        G[i1:i1+i2,] = 1
    else:
        G[:,i1:i1+i2] = 1
  
    # Add to the tensor
    images[i,:,:,:] = torch.Tensor(G).view(1,imgSize,imgSize)

# %% [markdown]
# #### Visualizing some images

# %%
fig,axes = plt.subplots(3,7,figsize=(9,6), dpi=135)

for i,ax in enumerate(axes.flatten()):
    
    whichpic = np.random.randint(nGauss)
    
    G = np.squeeze( images[whichpic,:,:] )
    
    ax.imshow(G,vmin=-1,vmax=1,cmap='jet')
    ax.set_xticks([])
    ax.set_yticks([])

plt.show()

# %% [markdown]
# ## 3. Custom Loss Functions

# %% [markdown]
# #### (i)  L1Loss function

# %%
# L1 loss function

class myL1Loss(nn.Module):
    
    def __init__(self):
        super().__init__()
        
    def forward(self, yhat, y):
        
        # MAE
        L1_loss = torch.mean(torch.abs(yhat-y))
        return L1_loss

# %% [markdown]
# #### (ii) L2 average loss

# %%
class myL2Avgloss(nn.Module):
    
    def __init__(self):
        super().__init__()
        
    def forward(self, yhat, y):
        
        # MSE part
        mse_loss = torch.mean( (yhat-y)**2 )
        
        # prediction average part
        pred_avg = torch.abs( torch.mean(yhat))
        
        return mse_loss+pred_avg

# %% [markdown]
# #### (iii) Correlation loss function

# %%
class myCorrLoss(nn.Module):
    
    def __init__(self):
        super().__init__()
        
    def forward(self, yhat, y):
        
        yhat_mean = torch.mean(yhat)
        y_mean = torch.mean(y)
        
        numerator = torch.sum( (yhat-yhat_mean)*(y - y_mean ))
        denominator = ( torch.numel(y) -1 )*torch.std(yhat)*torch.std(y)
        
        #  - : because we are trying to minimize the loss
        # postive correleation is good for the Model
        return -numerator/denominator

# %% [markdown]
# ## 4. Create the DL model

# %%
# create a class for the model
def makeTheNet(LossFunc, LR ):

    class gausnet(nn.Module):
        def __init__(self):
            super().__init__()
      
            # encoding layer
            self.enc = nn.Sequential(
                      nn.Conv2d(1,6,3,padding=1),
                      nn.ReLU(),
                      nn.MaxPool2d(2,2),
                
                      nn.Conv2d(6,4,3,padding=1),
                      nn.ReLU(),
                      nn.MaxPool2d(2,2)  
                      )
      
            # decoding layer
            # Not adding activation function in second layer because this is going to the final 
            # output of the Model.
            self.dec = nn.Sequential(
                      nn.ConvTranspose2d(4,6,3,2),
                      nn.ReLU(),
                      nn.ConvTranspose2d(6,1,3,2), 
              )

        def forward(self,x):
            return self.dec( self.enc(x) )
  
    # create the model instance
    net = gausnet()

    # loss function
    lossfunc = LossFunc
    #lossfunc = nn.MSELoss()

    # optimizer
    optimizer = torch.optim.Adam(net.parameters(),lr=LR)

    return net,lossfunc,optimizer

# %% [markdown]
# #### Testing the Model

# %%
# Test the model with one batch
net_test,lossfun_test,optimizer_test = makeTheNet(LossFunc=myL1Loss(), LR=.01)

yHat_test = net_test(images[:10,:,:,:])

# check size of output
print(' ')
print(yHat_test.shape)

# let's see how they look
fig,ax = plt.subplots(1,2,figsize=(8,3))

ax[0].imshow(torch.squeeze(images[0,0,:,:]).detach(),cmap='jet')
ax[0].set_title('Model input')

ax[1].imshow(torch.squeeze(yHat_test[0,0,:,:]).detach(),cmap='jet')
ax[1].set_title('Model output')

plt.show()
# Out:
#
# torch.Size([10, 1, 91, 91])

# %% [markdown]
# ## 5. Create a function that trains the model

# %%
# function that trains the model

def function2trainTheModel(Model, lossfunc, optimizer, epochs, Images=images, nGauss=nGauss ):
  
    # initialize losses
    losses = torch.zeros(epochs)

    # loop over epochs
    for epochi in range(epochs):

        # Pick a set of images at random
        pics2use = np.random.choice(nGauss, size=32,replace=False)
        X = Images[pics2use,:,:,:]

        # forward pass and loss
        yHat = Model(X)
        loss = lossfunc(yHat,X)
        losses[epochi] = loss.item()

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # end epochs

    # function output
    return losses,Model

# %% [markdown]
# ## 6.  Run the model

# %%
CNN_AE_Gaussian_model, lossfunc, Optimizer = makeTheNet(LossFunc=myL1Loss() , LR=0.01)

# %%
Losses,trained_Model= function2trainTheModel(Model=CNN_AE_Gaussian_model, 
                                             lossfunc=lossfunc, 
                                             optimizer=Optimizer, 
                                             epochs=200, 
                                             Images=images, 
                                             nGauss=nGauss )

# %% [markdown]
# ## 7. Results Visualization

# %%
plt.plot(Losses,'s-',label='Train')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title(f'Model loss :  {round(Losses[-1].item(),3)}')

plt.show()

# %% [markdown]
# ## 8. visualize some images

# %%
pics2use = np.random.choice(nGauss,size=32,replace=False)
X = images[pics2use,:,:,:]

yHat = trained_Model(X)

fig,axs = plt.subplots(2,7,figsize=(8,4), dpi=135)

for i in range(7):
    
    # Input image
    G = torch.squeeze( X[i,0,:,:] ).detach()
    G_mean = np.round(torch.mean(G).item(),2)
    
    # Output image
    O = torch.squeeze( yHat[i,0,:,:] ).detach()
    O_mean = np.round(torch.mean(O).item(), 2)
    
    # Plotting for input image
    axs[0,i].imshow(G,vmin=-1,vmax=1,cmap='jet')
#     axs[0,i].axis('off')
    axs[0,i].set_xticks([])
    axs[0,i].set_xlabel(f"mu:{G_mean}" )
    
    # Plotting for Output image
    axs[1,i].imshow(O,vmin=-1,vmax=1,cmap='jet')
#     axs[1,i].axis('off')
    axs[1,i].set_xticks([])
    axs[1,i].set_xlabel(f"mu:{O_mean}" )
    
    fig.tight_layout()
    
axs[0,0].set_title('Model input :') 
axs[1,0].set_title('Model output :')

plt.show()
